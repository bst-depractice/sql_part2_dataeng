# %%
# !pip install --quiet duckdb
# !pip install --quiet jupysql
# !pip install --quiet duckdb-engine
# !pip install --quiet pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.7/95.7 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.0/251.0 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.0/193.0 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 1.4 MB/s eta 0:00:00

# %%
import duckdb
import pandas as pd

# %load_ext sql
# Out:
# Deploy Dash apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Github

# %%
# !git clone https://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@github.com/orcascope/sql_part2_dataeng
# Out:
# Cloning into 'sql_part2_dataeng'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (12/12), 111.30 KiB | 749.00 KiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd sql_part2_dataeng
# Out:
# /content/drive/MyDrive/Github/sql_part2_dataeng

# %%
# conn = duckdb.connect("market.db")
# cursor = conn.cursor()

# %%
# df = cursor.execute("""
# show all tables
#   """).df()
# print(df)
# conn.commit()
# conn.close()

# %% [markdown]
# Use the helper functions
#
# `run_query()` to quickly read SQL queries into DataFrames
#
#
# `show_tables()` to return a list of all tables and views of the Chinook database, respectively.

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import duckdb
# %matplotlib inline

def run_query(q):
    with duckdb.connect('market.db') as conn:
        return pd.read_sql(q, conn)

def show_tables():
    q = """
    show all tables
    """
    return run_query(q)

show_tables()
# Out:
# <ipython-input-176-724053f8a882>:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(q, conn)
#   database schema                      name  \
# 0   market   main                     booth
# 1   market   main                  customer
# 2   market   main        customer_purchases
# 3   market   main          market_date_info
# 4   market   main                   product
# 5   market   main                    vendor
# 6   market   main  vendor_booth_assignments
# 7   market   main          vendor_inventory
# 8   market   main                  zip_data
#
#                                         column_names  \
# 0  [booth_number, booth_price_level, booth_descri...
# 1  [customer_id, customer_first_name, customer_la...
# 2  [product_id, vendor_id, market_date, customer_...
# ...

# %%
q="""
select * from booth
"""
run_query(q)
# Out:
# <ipython-input-176-724053f8a882>:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(q, conn)
#     booth_number booth_price_level  \
# 0              1                 A
# 1              2                 A
# 2              3                 B
# 3              4                 C
# 4              5                 C
# 5              6                 C
# 6              7                 A
# 7              8                 C
# 8              9                 C
# 9             10                 B
# 10            11                 B
# 11            12                 B
#
#                                     booth_description booth_type
# 0   First booth to the left as you enter the cente...   Standard
# 1   Second booth to the left as you enter the cent...   Standard
# ...
